# %% [markdown]
# # 1) Config

# %%
# === CONFIG ===
DATA_PATH   = "housing.csv"      # <- change me
TARGET      = "Overall_Homeless_Per_Capita"            # <- change me
OUTDIR      = "outputs"

FOLDS       = 5
N_SELECT    = 5
TUNE        = False                    # toggle tuning of best model
BLEND       = False                    # toggle blending of top models
IGNORE      = [ 'Overall Homeless',
                'Overall Homeless Individuals',
                'Overall Homeless People in Families',
                'Unsheltered Homeless',
                'Sheltered Total Homeless',
                'Overall_Homeless_Individuals_Per_Capita',
                'Overall_Homeless_People_in_Families_Per_Capita',
                'Unsheltered_Homeless_Per_Capita',
                'Sheltered_Homeless_Per_Capita']
SESSION_ID  = 222                     # random seed

# Optional: PyCaret setup knobs (kept same as script defaults)
TRAIN_SIZE                  = 0.8
NORMALIZE                   = True
TRANSFORM_TARGET            = False
REMOVE_MULTICOLLINEARITY    = True
MULTICOLLINEARITY_THRESHOLD = 0.95
VERBOSE_SETUP               = True
LOG_EXPERIMENT              = False

# %% [markdown]
# # 2) Imports & setup

# %%
# If needed:
# %pip install pycaret lightgbm catboost -q

import os
import pandas as pd

from pycaret.regression import (
    setup, compare_models, pull, tune_model, blend_models,
    finalize_model, predict_model, save_model, save_experiment
)

os.makedirs(OUTDIR, exist_ok=True)
pd.set_option("display.max_rows", 200)
pd.set_option("display.max_columns", 200)

# %% [markdown]
# # 3) Load data

# %%
df = pd.read_csv(DATA_PATH)
df = df.dropna()
display(df.head())
print(df.shape, "rows x columns")
# Out:
#    Total Population  Median Gross Rent  Median Household Income  Poverty_Rate  \
# 0            263206              59532                  3931531      8.837944
# 1            294038              69646                  4276757      8.086370
# 2            289982              72098                  4293890      8.044292
# 3            289010              73387                  4437615      8.016332
# 4            287529              75827                  4527440      9.103777
#
#    Vacancy_Rate  Renter_Household_Rate  Cost_Burdened_Rate  Unemployment_Rate  \
# 0      7.921203              39.721806           43.348727           7.143623
# 1      7.885972              40.565390           45.259545           6.718333
# 2      8.396699              40.757004           45.706091           6.087872
# 3      8.576839              40.898085           44.809796           5.806139
# 4      8.657760              40.044081           45.932310           5.663429
#
#    Total Year-Round Beds (ES, TH, SH)  Average Temperature  Overall Homeless  \
# 0                               988.0                 18.4            1023.0
# 1                              1019.0                  7.1            1208.0
# 2                              1007.0                 17.2            1105.0
# 3                              1023.0                  4.5            1128.0
# 4                              1028.0                  6.7            1094.0
#
#    Overall Homeless Individuals  Overall Homeless People in Families  \
# 0                         736.0                                287.0
# 1                         837.0                                371.0
# 2                         905.0                                200.0
# 3                         848.0                                280.0
# 4                         814.0                                280.0
#
#    Unsheltered Homeless  Sheltered Total Homeless  \
# 0                  53.0                     970.0
# 1                 179.0                    1029.0
# 2                 240.0                     865.0
# 3                 155.0                     973.0
# 4                  94.0                    1000.0
#
#    Overall_Homeless_Per_Capita  Overall_Homeless_Individuals_Per_Capita  \
# 0                     0.003887                                 0.002796
# 1                     0.004108                                 0.002847
# 2                     0.003811                                 0.003121
# 3                     0.003903                                 0.002934
# 4                     0.003805                                 0.002831
#
#    Overall_Homeless_People_in_Families_Per_Capita  \
# 0                                        0.001090
# 1                                        0.001262
# 2                                        0.000690
# 3                                        0.000969
# 4                                        0.000974
#
#    Unsheltered_Homeless_Per_Capita  Sheltered_Homeless_Per_Capita
# 0                         0.000201                       0.003685
# 1                         0.000609                       0.003500
# 2                         0.000828                       0.002983
# 3                         0.000536                       0.003367
# 4                         0.000327                       0.003478
# (3719, 20) rows x columns

# %% [markdown]
# # 4) PyCaret setup

# %%
_ = setup(
    data=df,
    target=TARGET,
    session_id=SESSION_ID,
    fold=FOLDS,
    train_size=TRAIN_SIZE,
    normalize=NORMALIZE,
    transform_target=TRANSFORM_TARGET,
    remove_multicollinearity=REMOVE_MULTICOLLINEARITY,
    multicollinearity_threshold=MULTICOLLINEARITY_THRESHOLD,
    ignore_features=IGNORE,
    verbose=VERBOSE_SETUP,
    log_experiment=LOG_EXPERIMENT,
)
# Out:
# <style type="text/css">
# #T_197ca_row9_col1, #T_197ca_row13_col1, #T_197ca_row15_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_197ca">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_197ca_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_197ca_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_197ca_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_197ca_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_197ca_row0_col1" class="data row0 col1" >222</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_197ca_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_197ca_row1_col1" class="data row1 col1" >Overall_Homeless_Per_Capita</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_197ca_row2_col0" class="data row2 col0" >Target type</td>
#       <td id="T_197ca_row2_col1" class="data row2 col1" >Regression</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_197ca_row3_col0" class="data row3 col0" >Original data shape</td>
#       <td id="T_197ca_row3_col1" class="data row3 col1" >(3719, 20)</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_197ca_row4_col0" class="data row4 col0" >Transformed data shape</td>
#       <td id="T_197ca_row4_col1" class="data row4 col1" >(3719, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_197ca_row5_col0" class="data row5 col0" >Transformed train set shape</td>
#       <td id="T_197ca_row5_col1" class="data row5 col1" >(2975, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_197ca_row6_col0" class="data row6 col0" >Transformed test set shape</td>
#       <td id="T_197ca_row6_col1" class="data row6 col1" >(744, 9)</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_197ca_row7_col0" class="data row7 col0" >Ignore features</td>
#       <td id="T_197ca_row7_col1" class="data row7 col1" >9</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_197ca_row8_col0" class="data row8 col0" >Numeric features</td>
#       <td id="T_197ca_row8_col1" class="data row8 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_197ca_row9_col0" class="data row9 col0" >Preprocess</td>
#       <td id="T_197ca_row9_col1" class="data row9 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_197ca_row10_col0" class="data row10 col0" >Imputation type</td>
#       <td id="T_197ca_row10_col1" class="data row10 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_197ca_row11_col0" class="data row11 col0" >Numeric imputation</td>
#       <td id="T_197ca_row11_col1" class="data row11 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_197ca_row12_col0" class="data row12 col0" >Categorical imputation</td>
#       <td id="T_197ca_row12_col1" class="data row12 col1" >mode</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_197ca_row13_col0" class="data row13 col0" >Remove multicollinearity</td>
#       <td id="T_197ca_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_197ca_row14_col0" class="data row14 col0" >Multicollinearity threshold</td>
#       <td id="T_197ca_row14_col1" class="data row14 col1" >0.950000</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_197ca_row15_col0" class="data row15 col0" >Normalize</td>
#       <td id="T_197ca_row15_col1" class="data row15 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_197ca_row16_col0" class="data row16 col0" >Normalize method</td>
#       <td id="T_197ca_row16_col1" class="data row16 col1" >zscore</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_197ca_row17_col0" class="data row17 col0" >Fold Generator</td>
#       <td id="T_197ca_row17_col1" class="data row17 col1" >KFold</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_197ca_row18_col0" class="data row18 col0" >Fold Number</td>
#       <td id="T_197ca_row18_col1" class="data row18 col1" >5</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_197ca_row19_col0" class="data row19 col0" >CPU Jobs</td>
#       <td id="T_197ca_row19_col1" class="data row19 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_197ca_row20_col0" class="data row20 col0" >Use GPU</td>
#       <td id="T_197ca_row20_col1" class="data row20 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_197ca_row21_col0" class="data row21 col0" >Log Experiment</td>
#       <td id="T_197ca_row21_col1" class="data row21 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_197ca_row22_col0" class="data row22 col0" >Experiment Name</td>
#       <td id="T_197ca_row22_col1" class="data row22 col1" >reg-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_197ca_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_197ca_row23_col0" class="data row23 col0" >USI</td>
#       <td id="T_197ca_row23_col1" class="data row23 col1" >6e67</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# # 5) Compare models & capture leaderboard

# %%
top_models = compare_models(n_select=N_SELECT, sort="R2")
leaderboard = pull()
leaderboard.to_csv(os.path.join(OUTDIR, "leaderboard.csv"), index=False)
display(leaderboard.head(20))

# Get the single best (first) model whether list or estimator
best_model = top_models[0] if isinstance(top_models, list) else top_models
# Out:
# <style type="text/css">
# #T_a2be9 th {
#   text-align: left;
# }
# #T_a2be9_row0_col0, #T_a2be9_row0_col1, #T_a2be9_row1_col0, #T_a2be9_row1_col4, #T_a2be9_row1_col6, #T_a2be9_row2_col0, #T_a2be9_row2_col1, #T_a2be9_row2_col3, #T_a2be9_row2_col4, #T_a2be9_row2_col5, #T_a2be9_row2_col6, #T_a2be9_row3_col0, #T_a2be9_row3_col1, #T_a2be9_row3_col3, #T_a2be9_row3_col4, #T_a2be9_row3_col5, #T_a2be9_row3_col6, #T_a2be9_row4_col0, #T_a2be9_row4_col1, #T_a2be9_row4_col3, #T_a2be9_row4_col4, #T_a2be9_row4_col5, #T_a2be9_row4_col6, #T_a2be9_row5_col0, #T_a2be9_row5_col1, #T_a2be9_row5_col3, #T_a2be9_row5_col4, #T_a2be9_row5_col5, #T_a2be9_row5_col6, #T_a2be9_row6_col0, #T_a2be9_row6_col1, #T_a2be9_row6_col3, #T_a2be9_row6_col4, #T_a2be9_row6_col5, #T_a2be9_row6_col6, #T_a2be9_row7_col0, #T_a2be9_row7_col1, #T_a2be9_row7_col3, #T_a2be9_row7_col4, #T_a2be9_row7_col5, #T_a2be9_row7_col6, #T_a2be9_row8_col0, #T_a2be9_row8_col1, #T_a2be9_row8_col3, #T_a2be9_row8_col4, #T_a2be9_row8_col5, #T_a2be9_row8_col6, #T_a2be9_row9_col0, #T_a2be9_row9_col1, #T_a2be9_row9_col3, #T_a2be9_row9_col4, #T_a2be9_row9_col5, #T_a2be9_row9_col6, #T_a2be9_row10_col0, #T_a2be9_row10_col1, #T_a2be9_row10_col3, #T_a2be9_row10_col4, #T_a2be9_row10_col5, #T_a2be9_row10_col6, #T_a2be9_row11_col0, #T_a2be9_row11_col1, #T_a2be9_row11_col3, #T_a2be9_row11_col4, #T_a2be9_row11_col5, #T_a2be9_row11_col6, #T_a2be9_row12_col0, #T_a2be9_row12_col1, #T_a2be9_row12_col3, #T_a2be9_row12_col4, #T_a2be9_row12_col5, #T_a2be9_row12_col6, #T_a2be9_row13_col0, #T_a2be9_row13_col1, #T_a2be9_row13_col3, #T_a2be9_row13_col4, #T_a2be9_row13_col5, #T_a2be9_row13_col6, #T_a2be9_row14_col0, #T_a2be9_row14_col1, #T_a2be9_row14_col3, #T_a2be9_row14_col4, #T_a2be9_row14_col5, #T_a2be9_row14_col6, #T_a2be9_row15_col0, #T_a2be9_row15_col1, #T_a2be9_row15_col3, #T_a2be9_row15_col4, #T_a2be9_row15_col5, #T_a2be9_row15_col6, #T_a2be9_row16_col0, #T_a2be9_row16_col1, #T_a2be9_row16_col3, #T_a2be9_row16_col4, #T_a2be9_row16_col5, #T_a2be9_row16_col6, #T_a2be9_row17_col0, #T_a2be9_row17_col1, #T_a2be9_row17_col3, #T_a2be9_row17_col4, #T_a2be9_row17_col5, #T_a2be9_row17_col6, #T_a2be9_row18_col0, #T_a2be9_row18_col1, #T_a2be9_row18_col3, #T_a2be9_row18_col4, #T_a2be9_row18_col5, #T_a2be9_row18_col6 {
#   text-align: left;
# }
# #T_a2be9_row0_col2, #T_a2be9_row0_col3, #T_a2be9_row0_col4, #T_a2be9_row0_col5, #T_a2be9_row0_col6, #T_a2be9_row1_col1, #T_a2be9_row1_col2, #T_a2be9_row1_col3, #T_a2be9_row1_col5, #T_a2be9_row2_col2, #T_a2be9_row3_col2, #T_a2be9_row4_col2, #T_a2be9_row5_col2, #T_a2be9_row6_col2, #T_a2be9_row7_col2, #T_a2be9_row8_col2, #T_a2be9_row9_col2, #T_a2be9_row10_col2, #T_a2be9_row11_col2, #T_a2be9_row12_col2, #T_a2be9_row13_col2, #T_a2be9_row14_col2, #T_a2be9_row15_col2, #T_a2be9_row16_col2, #T_a2be9_row17_col2, #T_a2be9_row18_col2 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_a2be9_row0_col7, #T_a2be9_row1_col7, #T_a2be9_row2_col7, #T_a2be9_row3_col7, #T_a2be9_row4_col7, #T_a2be9_row5_col7, #T_a2be9_row6_col7, #T_a2be9_row7_col7, #T_a2be9_row9_col7, #T_a2be9_row10_col7, #T_a2be9_row11_col7, #T_a2be9_row12_col7, #T_a2be9_row13_col7, #T_a2be9_row15_col7, #T_a2be9_row16_col7, #T_a2be9_row17_col7 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_a2be9_row8_col7, #T_a2be9_row14_col7, #T_a2be9_row18_col7 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_a2be9">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_a2be9_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_a2be9_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_a2be9_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_a2be9_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_a2be9_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_a2be9_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_a2be9_level0_col6" class="col_heading level0 col6" >MAPE</th>
#       <th id="T_a2be9_level0_col7" class="col_heading level0 col7" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_a2be9_level0_row0" class="row_heading level0 row0" >catboost</th>
#       <td id="T_a2be9_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_a2be9_row0_col1" class="data row0 col1" >0.0005</td>
#       <td id="T_a2be9_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_a2be9_row0_col3" class="data row0 col3" >0.0008</td>
#       <td id="T_a2be9_row0_col4" class="data row0 col4" >0.7869</td>
#       <td id="T_a2be9_row0_col5" class="data row0 col5" >0.0008</td>
#       <td id="T_a2be9_row0_col6" class="data row0 col6" >0.3289</td>
#       <td id="T_a2be9_row0_col7" class="data row0 col7" >1.3900</td>
#     </tr>
#     <tr>
#       <th id="T_a2be9_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_a2be9_row1_col0" class="data row1 col0" >Extra Trees Regressor</td>
#       <td id="T_a2be9_row1_col1" class="data row1 col1" >0.0004</td>
#       <td id="T_a2be9_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_a2be9_row1_col3" class="data row1 col3" >0.0008</td>
#       <td id="T_a2be9_row1_col4" class="data row1 col4" >0.7798</td>
#       <td id="T_a2be9_row1_col5" class="data row1 col5" >0.0008</td>
#       <td id="T_a2be9_row1_col6" class="data row1 col6" >0.3294</td>
#       <td id="T_a2be9_row1_col7" class="data row1 col7" >0.1720</td>
#     </tr>
#     <tr>
#       <th id="T_a2be9_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_a2be9_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_a2be9_row2_col1" class="data row2 col1" >0.0005</td>
#       <td id="T_a2be9_row2_col2" class="data row2 col2" >0.0000</td>
#       <td id="T_a2be9_row2_col3" class="data row2 col3" >0.0009</td>
#       <td id="T_a2be9_row2_col4" class="data row2 col4" >0.7468</td>
#       <td id="T_a2be9_row2_col5" class="data row2 col5" >0.0009</td>
#       <td id="T_a2be9_row2_col6" class="data row2 col6" >0.3464</td>
#       <td id="T_a2be9_row2_col7" class="data row2 col7" >0.1100</td>
#     </tr>
#     <tr>
#       <th id="T_a2be9_level0_row3" class="row_heading level0 row3" >rf</th>
#       <td id="T_a2be9_row3_col0" class="data row3 col0" >Random Forest Regressor</td>
#       <td id="T_a2be9_row3_col1" class="data row3 col1" >0.0005</td>
#       <td id="T_a2be9_row3_col2" class="data row3 col2" >0.0000</td>
#       <td id="T_a2be9_row3_col3" class="data row3 col3" >0.0009</td>
#       <td id="T_a2be9_row3_col4" class="data row3 col4" >0.7315</td>
#       <td id="T_a2be9_row3_col5" class="data row3 col5" >0.0009</td>
#       <td id="T_a2be9_row3_col6" class="data row3 col6" >0.3481</td>
#       <td id="T_a2be9_row3_col7" class="data row3 col7" >0.4340</td>
#     </tr>
#     <tr>
#       <th id="T_a2be9_level0_row4" class="row_heading level0 row4" >gbr</th>
#       <td id="T_a2be9_row4_col0" class="data row4 col0" >Gradient Boosting Regressor</td>
#       <td id="T_a2be9_row4_col1" class="data row4 col1" >0.0006</td>
#       <td id="T_a2be9_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_a2be9_row4_col3" class="data row4 col3" >0.0010</td>
#       <td id="T_a2be9_row4_col4" class="data row4 col4" >0.6686</td>
#       <td id="T_a2be9_row4_col5" class="data row4 col5" >0.0010</td>
#       <td id="T_a2be9_row4_col6" class="data row4 col6" >0.4305</td>
#       <td id="T_a2be9_row4_col7" class="data row4 col7" >0.1840</td>
#     </tr>
#     <tr>
#       <th id="T_a2be9_level0_row5" class="row_heading level0 row5" >knn</th>
#       <td id="T_a2be9_row5_col0" class="data row5 col0" >K Neighbors Regressor</td>
#       <td id="T_a2be9_row5_col1" class="data row5 col1" >0.0006</td>
#       <td id="T_a2be9_row5_col2" class="data row5 col2" >0.0000</td>
#       <td id="T_a2be9_row5_col3" class="data row5 col3" >0.0010</td>
#       <td id="T_a2be9_row5_col4" class="data row5 col4" >0.6583</td>
#       <td id="T_a2be9_row5_col5" class="data row5 col5" >0.0010</td>
#       <td id="T
#                                     Model     MAE  MSE    RMSE      R2  \
# catboost               CatBoost Regressor  0.0005  0.0  0.0008  0.7869
# et                  Extra Trees Regressor  0.0004  0.0  0.0008  0.7798
# lightgbm  Light Gradient Boosting Machine  0.0005  0.0  0.0009  0.7468
# rf                Random Forest Regressor  0.0005  0.0  0.0009  0.7315
# gbr           Gradient Boosting Regressor  0.0006  0.0  0.0010  0.6686
# knn                 K Neighbors Regressor  0.0006  0.0  0.0010  0.6583
# dt                Decision Tree Regressor  0.0006  0.0  0.0013  0.4422
# br                         Bayesian Ridge  0.0009  0.0  0.0015  0.3382
# lar                Least Angle Regression  0.0009  0.0  0.0015  0.3381
# ridge                    Ridge Regression  0.0009  0.0  0.0015  0.3381
# lr                      Linear Regression  0.0009  0.0  0.0015  0.3381
# omp           Orthogonal Matching Pursuit  0.0010  0.0  0.0016  0.2296
# huber                     Huber Regressor  0.0009  0.0  0.0016  0.1986
# lasso                    Lasso Regression  0.0012  0.0  0.0018 -0.0018
# en                            Elastic Net  0.0012  0.0  0.0018 -0.0018
# llar         Lasso Least Angle Regression  0.0012  0.0  0.0018 -0.0018
# dummy                     Dummy Regressor  0.0012  0.0  0.0018 -0.0018
# ada                    AdaBoost Regressor  0.0017  0.0  0.0019 -0.1044
# par          Passive Aggressive Regressor  0.0018  0.0  0.0026 -1.0549
#
#            RMSLE    MAPE  TT (Sec)
# catboost  0.0008  0.3289     1.390
# et        0.0008  0.3294     0.172
# lightgbm  0.0009  0.3464     0.110
# rf        0.0009  0.3481     0.434
# gbr       0.0010  0.4305     0.184
# knn       0.0010  0.4306     0.044
# dt        0.0013  0.4105     0.032
# br        0.0014  0.7461     0.028
# lar       0.0014  0.7462     0.026
# ridge     0.0014  0.7462     0.038
# lr        0.0014  0.7462     1.206
# omp       0.0016  0.8470     0.028
# huber     0.0016  0.5680     0.030
# lasso     0.0018  1.0766     0.620
# en        0.0018  1.0766     0.026
# llar      0.0018  1.0766     0.028
# dummy     0.0018  1.0766     0.030
# ada       0.0019  1.8322     0.084
# par       0.0025  1.0000     0.026

# %% [markdown]
# # 6) Optional: Tune best model

# %%
if TUNE:
    best_model = tune_model(best_model, optimize="R2")
    tuned_results = pull()
    display(tuned_results.head())

# %% [markdown]
# # 7) Optional: Blend top models (graceful if incompatible)

# %%
if BLEND and isinstance(top_models, list) and len(top_models) > 1:
    try:
        # blend up to the top 3 models by R2
        blended = blend_models(top_models[:min(3, len(top_models))], optimize="R2")
        blended_results = pull()
        display(blended_results.head())
        # Simple policy: keep the last trained model (blended) as "best"
        best_model = blended
    except Exception as e:
        print("Blending skipped due to:", repr(e))

# %% [markdown]
# # 8) Finalize on full training partition & evaluate holdout

# %%
final_model = finalize_model(best_model)

# Evaluate on hold-out set held inside PyCaret
holdout_preds = predict_model(final_model)   # returns a dataframe with predictions
holdout_path  = os.path.join(OUTDIR, "holdout_predictions.csv")
holdout_preds.to_csv(holdout_path, index=False)
display(holdout_preds.head())
print("Saved:", holdout_path)
# Out:
# <style type="text/css">
# </style>
# <table id="T_15308">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15308_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_15308_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_15308_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_15308_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_15308_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_15308_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_15308_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15308_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15308_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_15308_row0_col1" class="data row0 col1" >0.0003</td>
#       <td id="T_15308_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_15308_row0_col3" class="data row0 col3" >0.0005</td>
#       <td id="T_15308_row0_col4" class="data row0 col4" >0.9357</td>
#       <td id="T_15308_row0_col5" class="data row0 col5" >0.0005</td>
#       <td id="T_15308_row0_col6" class="data row0 col6" >0.2190</td>
#     </tr>
#   </tbody>
# </table>
#       Total Population  Median Gross Rent  Median Household Income  \
# 2705           1235371             346174                 19394874
# 1217            101744              29490                  2081070
# 3412            277956              52806                  3334185
# 2653           2034094             956963                 54818010
# 390              62798              12867                   686097
#
#       Poverty_Rate  Vacancy_Rate  Renter_Household_Rate  Cost_Burdened_Rate  \
# 2705     18.513466     13.938038              40.521450           48.248928
# 1217     15.024964     12.575393              30.953615           36.398903
# 3412     13.451769      9.225744              33.123146           42.988457
# 2653      6.552794      8.097219              21.629889           53.473621
# 390      18.239435     20.464594              36.373993           44.720032
#
#       Unemployment_Rate  Total Year-Round Beds (ES, TH, SH)  \
# 2705          11.560264                              1936.0
# 1217           7.315742                                88.0
# 3412           5.303014                               490.0
# 2653           4.754526                              3206.0
# 390           11.098045                                81.0
#
#       Average Temperature  Overall_Homeless_Per_Capita  prediction_label
# 2705            19.799999                     0.001702          0.001683
# 1217            22.200001                     0.000914          0.000751
# 3412            40.099998                     0.000961          0.001490
# 2653            15.800000                     0.001492          0.001434
# 390             48.599998                     0.002166          0.003933
# Saved: outputs\holdout_predictions.csv

# %% [markdown]
# # 9) Save artifacts

# %%
# Save pipeline (includes preprocessing + model)
pipeline_path_no_ext = os.path.join(OUTDIR, "best_pipeline")
save_model(final_model, pipeline_path_no_ext)  # creates best_pipeline.pkl (+ JSON)

# Save full experiment (version-dependent in PyCaret; wrap in try)
try:
    experiment_path = os.path.join(OUTDIR, "experiment.pkl")
    save_experiment(experiment_path)
    print("Saved experiment to:", experiment_path)
except Exception as e:
    print("save_experiment not available in this PyCaret version:", repr(e))
# Out:
# Transformation Pipeline and Model Successfully Saved
# Saved experiment to: outputs\experiment.pkl

# %% [markdown]
# # 10) (Optional) Predict on the full input CSV

# %%
full_preds = predict_model(final_model, data=df)
full_preds_path = os.path.join(OUTDIR, "full_data_with_predictions.csv")
full_preds.to_csv(full_preds_path, index=False)
display(full_preds.head())
print("Saved:", full_preds_path)
# Out:
# <style type="text/css">
# </style>
# <table id="T_7a976">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7a976_level0_col0" class="col_heading level0 col0" >Model</th>
#       <th id="T_7a976_level0_col1" class="col_heading level0 col1" >MAE</th>
#       <th id="T_7a976_level0_col2" class="col_heading level0 col2" >MSE</th>
#       <th id="T_7a976_level0_col3" class="col_heading level0 col3" >RMSE</th>
#       <th id="T_7a976_level0_col4" class="col_heading level0 col4" >R2</th>
#       <th id="T_7a976_level0_col5" class="col_heading level0 col5" >RMSLE</th>
#       <th id="T_7a976_level0_col6" class="col_heading level0 col6" >MAPE</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7a976_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_7a976_row0_col0" class="data row0 col0" >CatBoost Regressor</td>
#       <td id="T_7a976_row0_col1" class="data row0 col1" >0.0002</td>
#       <td id="T_7a976_row0_col2" class="data row0 col2" >0.0000</td>
#       <td id="T_7a976_row0_col3" class="data row0 col3" >0.0004</td>
#       <td id="T_7a976_row0_col4" class="data row0 col4" >0.9614</td>
#       <td id="T_7a976_row0_col5" class="data row0 col5" >0.0004</td>
#       <td id="T_7a976_row0_col6" class="data row0 col6" >0.1993</td>
#     </tr>
#   </tbody>
# </table>
#    Total Population  Median Gross Rent  Median Household Income  Poverty_Rate  \
# 0            263206              59532                  3931531      8.837944
# 1            294038              69646                  4276757      8.086370
# 2            289982              72098                  4293890      8.044292
# 3            289010              73387                  4437615      8.016332
# 4            287529              75827                  4527440      9.103777
#
#    Vacancy_Rate  Renter_Household_Rate  Cost_Burdened_Rate  Unemployment_Rate  \
# 0      7.921203              39.721806           43.348728           7.143623
# 1      7.885972              40.565392           45.259544           6.718333
# 2      8.396699              40.757004           45.706089           6.087873
# 3      8.576838              40.898087           44.809795           5.806139
# 4      8.657761              40.044083           45.932308           5.663429
#
#    Total Year-Round Beds (ES, TH, SH)  Average Temperature  ...  \
# 0                               988.0            18.400000  ...
# 1                              1019.0             7.100000  ...
# 2                              1007.0            17.200001  ...
# 3                              1023.0             4.500000  ...
# 4                              1028.0             6.700000  ...
#
#    Overall Homeless Individuals  Overall Homeless People in Families  \
# 0                         736.0                                287.0
# 1                         837.0                                371.0
# 2                         905.0                                200.0
# 3                         848.0                                280.0
# 4                         814.0                                280.0
#
#    Unsheltered Homeless  Sheltered Total Homeless  \
# 0                  53.0                     970.0
# 1                 179.0                    1029.0
# 2                 240.0                     865.0
# 3                 155.0                     973.0
# 4                  94.0                    1000.0
#
#    Overall_Homeless_Individuals_Per_Capita  \
# 0                                 0.002796
# 1                                 0.002847
# 2                                 0.003121
# 3                                 0.002934
# 4                                 0.002831
#
#    Overall_Homeless_People_in_Families_Per_Capita  \
# 0                                        0.001090
# 1                                        0.001262
# 2                                        0.000690
# 3                                        0.000969
# 4                                        0.000974
#
#    Unsheltered_Homeless_Per_Capita  Sheltered_Homeless_Per_Capita  \
# 0                         0.000201                       0.003685
# 1                         0.000609                       0.003500
# 2                         0.000828                       0.002983
# 3                         0.000536                       0.003367
# 4                         0.000327                       0.003478
#
#    Overall_Homeless_Per_Capita  prediction_label
# 0                     0.003887          0.003797
# 1                     0.004108          0.004054
# 2                     0.003811          0.003930
# 3                     0.003903          0.004012
# 4                     0.003805          0.004090
#
# [5 rows x 21 columns]
# Saved: outputs\full_data_with_predictions.csv

# %% [markdown]
# # 11) Quick summary

# %%
print("\n=== Done ===")
print(f"Artifacts saved in: {OUTDIR}")
print(" - leaderboard.csv")
print(" - holdout_predictions.csv")
print(" - full_data_with_predictions.csv")
print(" - best_pipeline.pkl (via save_model)")
print(" - experiment.pkl (via save_experiment, if supported)")
# Out:
# === Done ===
# Artifacts saved in: outputs
#  - leaderboard.csv
#  - holdout_predictions.csv
#  - full_data_with_predictions.csv
#  - best_pipeline.pkl (via save_model)
#  - experiment.pkl (via save_experiment, if supported)
